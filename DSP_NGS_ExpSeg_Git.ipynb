# %%
import os
import scipy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from openpyxl import load_workbook

from scipy import stats as stats
from copy import copy as copy

# %%
# read in paths from config file

configDict = {
    'rootDir': '',
    'initialDataPath' : '',
    'QCDataPath' : '',
    # 'labWorksheet01Path':'',
    'projectName':''
}

# with open(os.path.join(workingDir, 'config.txt'),'r') as f:
with open('config.txt','r') as f:
    lines = f.readlines()
    for line in lines:
        if not line.startswith('#'):
            line = line.strip()
            fields = line.split(':')

            if fields[0].strip()=='initialDataPath':
                configDict[fields[0].strip()] = fields[1].strip().strip('\'')
            else:
                configDict[fields[0].strip()] = fields[1].strip().strip('\'')
## ToDo: Add checks to ensure that minimal fields have been populated. Raise errors or warnings

# %%
configDict
# Out:
# {'rootDir': '/Users/upton6/Documents/Nanostring/Projects/NS_Coeliac/DSP_Output/',
#  'initialDataPath': 'Initial Dataset.xlsx',
#  'QCDataPath': 'Default_QC.xlsx',
#  'projectName': 'Subramaniam_msWTA',
#  'DCCPath': ''}

# %% [markdown]
# # Define functions

# %%
class master_data:
    def __init__(self, dataPath):
        ### import data from excel workbook
        
        self.wb = load_workbook(dataPath)
        self.segWs = self.wb['SegmentProperties']
        self.cntWs = self.wb['BioProbeCountMatrix']
        
        self.segValues = [[y.value for y in x] for x in self.segWs[self.segWs.calculate_dimension()]]
        self.cntValues = [[y.value for y in x] for x in self.cntWs[self.cntWs.calculate_dimension()]]

        self.dropData = False
        
        
    def get_data(self):
        ### Convert nested list to a pandas dataFrame and extract expression data with labels
        cntData = self.cntValues
        cntCols = self.cntValues[0]
        df = pd.DataFrame(self.cntValues)
        cntIndex = [x[0] for x in self.cntValues[1:]]
        cntDF = pd.DataFrame(self.cntValues[1:], index=cntIndex, columns=cntCols)
        self.counts = cntDF.iloc[:,12:]
        self.counts = self.counts.astype(np.float64)      # Convert datatype to float64
        self.priobeInfo = cntDF.iloc[:,:12]
        segCols = self.segValues[0]
        segIndex = [x[4].replace(' | ',('_')) for x in self.segValues[1:]]
        self.segData = pd.DataFrame(self.segValues[1:], index=segIndex, columns=segCols)

        self.dataOrig = self.counts.copy()
        self.dataLog1 = np.log2(self.counts+1)            # Log transform data for QC and analysis steps

        self.probeClass = False                           # Keep a copy of the original data before transformation or normalisation
        # self.probeClass = df.iloc[self.targIdx:,2]      ### Index needs updating here also
        # self.probeClass.rename(index=rowLabels, inplace=True)
        # self.probeClass.rename(index='ProbeClass', inplace=True)

        # ToDo: Need to update probeclass handling and labeling
        
        self.probeClassDict = {
            'Positive': 'A',
            'Negative': 'B',
            'Control': 'C',
            'Endogenous': 'E'}

        return(self.counts, self.priobeInfo, self.segData)

    def get_descriptors(self):
        pass

    def add_class_mean(self, df):
        pass

    def drop_AOIs(self, includes, writeOrig=False):
        pass
        
    def set_threshold(self, threshold):
        self.threshold = threshold
        # ToDo: Check that all values in master data are also included in threshold dataFrame
        # ToDo: Convert threshold data to 0/1 data if needed

    def drop_probes(self, labels):
        pass

# %%
def plot_SA_Hist(surfArea):
    fig, ax = plt.subplots(figsize=(10,5))
    ax.hist(surfArea, bins=50)
    ax.set_xlabel('AOI Surface Area µm', fontdict=labelFont)
    ax.set_ylabel('Count', fontdict=labelFont)
    ax.set_title('AOI Surface Area distribution', fontdict=titleFont)
    print('Min SA')
    print(min(surfArea))
    print('Max SA')
    print(max(surfArea))
    return(fig)

# %%
# Plot log2 transformed raw data before any normalisation

def draw_probe_plot(dataRaw, dataSortedRaw, namedColourList, title, exp=False, violin=False):
    
    fig, ax = plt.subplots(figsize=(15,8))
    
    if exp:
        ax.boxplot(np.exp2(dataRaw.drop(labels=['mean','probeClass'], axis=1).reindex(labels=dataSortedRaw.index).T) -1, sym='-', labels=dataSortedRaw.index)
    else:
        ax.boxplot(dataRaw.drop(labels=['mean','probeClass'], axis=1).reindex(labels=dataSortedRaw.index).T, sym='-', labels=dataSortedRaw.index)

    
    if violin:
        if exp:
            ax.violinplot(np.exp2(dataRaw.drop(labels=['mean','probeClass'], axis=1).reindex(labels=dataSortedRaw.index).T) -1)

    #         ax.boxplot(np.exp2(dataRaw.drop(labels=['mean','probeClass'], axis=1).reindex(labels=dataSortedRaw.index).T) -1, sym='-', labels=dataSortedRaw.index)
        else:
            ax.violinplot(dataRaw.drop(labels=['mean','probeClass'], axis=1).reindex(labels=dataSortedRaw.index).T)

    #         ax.boxplot(dataRaw.drop(labels=['mean','probeClass'], axis=1).reindex(labels=dataSortedRaw.index).T, sym='-', labels=dataSortedRaw.index)
        
        
    else:


        for i,j in enumerate(dataSortedRaw.index):
            y = dataRaw.drop(labels=['mean','probeClass'], axis=1).loc[j]
            colours = [namedColourList[2] if v.split('_')[-1] == 'Tumour' else namedColourList[5] if v.split('_')[-1] == 'TME' else namedColourList[1] for v in y.index]
        #     colours = [colourList[2] if v.split('_')[-1] == 'Tumour' else colourList[5] if v.split('_')[-1] == 'Immune' else colourList[1] for v in y.index]
            y = y
            if exp:
                y = np.exp2(y.values)-1
            else:
                y = y.values

            x = np.random.normal(i+1, 0.1, len(y))

            for i in range(len(x)): 
                ax.plot(x[i], y[i], c=colours[i], marker='.', alpha=0.25)

    ax.set_xticks(np.arange(1,len(dataSortedRaw.index)+1,1))
    ax.set_xlabel=list(dataSortedRaw.index)
    
    print(len(np.arange(0,len(dataSortedRaw.index),1)))
    print(len(list(dataSortedRaw.index)))
    
    ax.tick_params(axis='x', labelrotation = 90)
    

    if exp:
        ax.semilogy()
        ax.set_title(title + ' (untransformed)', size=36)
        ax.set_ylabel('Probe value', size=24)
    else:
        ax.set_title(title + ' (Log2 transformed)', size=36)
        ax.set_ylabel('Log2 probe value', size=24)
#     plt.show()
    
    return(fig)

# %%
def probe_GeoMean_Plots(plotData, title=''):
    rows=1
    cols=2
    colours = [namedColourList[2] if x.split('_')[-1] == 'Tumour' else namedColourList[5] if x.split('_')[-1] == 'TME' else namedColourList[1] for x in HKGeoMean.index]

    fig,ax = plt.subplots(rows,cols, sharey=True, gridspec_kw={'width_ratios': [4,1]}, figsize=(15,5))
    ax[0].bar(np.linspace(1,len(plotData),len(plotData)), plotData, color=colours)
    ax[1].hist(plotData, bins=int(len(plotData)/10),orientation='horizontal', color='k')
    ax[0].set_xlim(0,len(plotData))
    
    ax[0].text(2,max(plotData)*.95,'Tumour', size=20, c=namedColourList[2])
    ax[0].text(2,max(plotData)*.825,'TME', size=20, c=namedColourList[5])
    ax[0].text(2,max(plotData)*.7,'Other', size=20, c=namedColourList[1])

    fig.suptitle(title, size=36)
    ax[0].set_ylabel('Probe Value', size=18)
    ax[0].set_xlabel('Probes', size=18)
    ax[1].set_xlabel('Count', size=18)

    fig.tight_layout()

# %%
class threshold_probes:
    def __init__(self, data, bins):
        
        self.data = data.drop(labels=['mean','probeClass'], axis=1)
        self.bins = bins
        self.thisHist = plt.hist(self.data.values.flatten(), bins = self.bins)

    def zoom_plot(self, start, end):
        plt.hist(self.data.values.flatten(), bins = self.bins)
        plt.xlim(0,3)        
        
    def check_threshold(self, start, end):
        print(self.thisHist[0][start:end])
        print(self.thisHist[1][start:end])

    def set_threshold_idx(self, idx):
        print(self.thisHist[0][idx])
        print(self.thisHist[1][idx])
        
        self.threshold_idx = idx
        self.threshold = self.thisHist[1][idx]

    def get_filter(self):
        self.ETfilter = self.data >= self.threshold
        return(self.ETfilter)

# %%
def binding_density_plot(sampleInfoExternal, selectedInfo, subSelection):
    # print('selectedInfo')
    # print(selectedInfo)
    
    if not (subSelection == None):
        selectedInfo = selectedInfo.loc[subSelection]
    if (type(selectedInfo) == pd.core.series.Series):
        selectedInfo = pd.DataFrame(selectedInfo).T
        
    comboUniques = []
    comboColourDictRev = {}
    for c in selectedInfo.columns:
        thisCol = selectedInfo[c]
        combined = '_'.join(thisCol.values)
        comboUniques.append(combined)
        comboColourDictRev[c] = combined
    comboUniques = sorted(list(set(comboUniques)))
    print('\nNumber of unique combinations: {}'.format(len(comboUniques)))
    # print(comboColourDictRev)

    gradient = np.linspace(0, 1, len(comboUniques))
    gradDict = dict(zip(comboUniques,gradient))
    
    sampleInfoExternal.sort_values(by=['Plate', 'Col', 'Row'], axis=1, inplace=True)
    # Binding Density plot:
    plt.figure(figsize=(40,10))
    my_cmap = plt.get_cmap("nipy_spectral")
    
    colours = []
    for c in sampleInfoExternal.columns:
        colours.append(gradDict[comboColourDictRev[c]])
    
    print('selectedInfo.index')
    print(list(selectedInfo.index))

    fig, ax = plt.subplots(figsize=(20,5))

    
    bar = ax.bar(sampleInfoExternal.columns,
            sampleInfoExternal.loc['BindingDensity'].values.astype(np.float32), 
            color=my_cmap(colours)
           )#, bottom=0)
    ax.set_title('_'.join(selectedInfo.index))
    ax.set_xticklabels(sampleInfoExternal.columns, rotation='vertical')
    # ax.legend()
    plt.show()

# ToDo: Add legend

# %% [markdown]
# # Import data from Nanostring initial dataset file.

# %%
dataPath = os.path.join(configDict['rootDir'],configDict['initialDataPath'])
dataPath = os.path.join(configDict['rootDir'],configDict['QCDataPath'])

masterData = master_data(dataPath)


counts, probes, segs = masterData.get_data()


counts

# probes

# segs
# Out:
# /Users/upton6/anaconda3/envs/nanoeda/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#        TRI-QUT Coeliac Study_TMA Block 4 | 001 | Segment 1  \
# 48107                                              149.0
# 45080                                              125.0
# 48627                                               61.0
# 36143                                               41.0
# 41381                                               53.0
# ...                                                  ...
# 44262                                              133.0
# 37145                                               42.0
# 51325                                              262.0
# 50331                                               70.0
# 37173                                               98.0
#
#        TRI-QUT Coeliac Study_TMA Block 4 | 001 | Segment 2  \
# 48107                                               50.0
# 45080                                               50.0
# 48627                                               45.0
# 36143                                               24.0
# 41381                                               37.0
# ...                                                  ...
# 44262                                               79.0
# 37145                                               42.0
# 51325                                               66.0
# 50331                                               44.0
# 37173                                               50.0
#
#        TRI-QUT Coeliac Study_TMA Block 4 | 002 | Segment 1  \
# 48107                                              297.0
# 45080                                              144.0
# 48627                                               64.0
# 36143                                               75.0
# 41381                                               70.0
# ...                                                  ...
# 44262                                              127.0
# 37145                                               41.0
# 51325                                              180.0
# 50331                                               67.0
# 37173                                              108.0
#
#        TRI-QUT Coeliac Study_TMA Block 4 | 002 | Segment 2  \
# 48107                                               67.0
# 45080                                               55.0
# 48627                                               49.0
# 36143                                               49.0
# 41381                                               51.0
# ...                                                  ...
# 44262                                              100.0
# 37145                                               50.0
# 51325                                               47.0
# 50331                                               51.0
# 37173                                               77.0
#
#        TRI-QUT Coeliac Study_TMA Block 4 | 003 | Segment 1  \
# 48107                                              234.0
# 45080                                              208.0
# 48627                                               91.0
# 36143                                               68.0
# 41381                                               79.0
# ...                                                  ...
# 44262                                              211.0
# 37145                                               47.0
# 51325                                              452.0
# 50331                                              114.0
# 37173                                              131.0
#
#        TRI-QUT Coeliac Study_TMA Block 4 | 003 | Segment 2  \
# 48107                                               29.0
# 45080                                               42.0
# 48627                                               24.0
# 36143                                               26.0
# 41381                                               23.0
# ...                                                  ...
# 44262                                               50.0
# 37145                                               28.0
# 51325                                               51.0
# 50331                                               27.0
# 37173                                               33.0
#
#        TRI-QUT Coeliac Study_TMA Block 4 | 004 | Segment 1  \
# 48107                                              447.0
# 45080                                              190.0
# 48627                                               71.0
# 36143                                               62.0
# 41381                                               69.0
# ...                                                  ...
# 44262                                              195.0
# 37145                                               62.0
# 51325                                              340.0
# 50331                                               87.0
# 37173                                              137.0
#
#        TRI-QUT Coeliac Study_TMA Block 4 | 004 | Segment 2  \
# 48107                                               43.0
# 45080                                               59.0
# 48627                                               31.0
# 36143                                               38.0
# 41381                                               35.0
# ...                                                  ...
# 44262                                               74.0
# 37145                                               31.0
# 51325                                               61.0
# 50331                                               40.0
# 37173                                               47.0
#
#        TRI-QUT Coeliac Study_TMA Block 4 | 005 | Segment 1  \
# 48107                                              612.0
# 45080                                              162.0
# 48627                                               73.0
# 36143                                               69.0
# 41381                                               41.0
# ...                                                  ...
# 44262                                              162.0
# 37145                                               44.0
# 51325                                              249.0
# 50331                                               71.0
# 37173                                              123.0
#
#        TRI-QUT Coeliac Study_TMA Block 4 | 005 | Segment 2  ...  \
# 48107                                               47.0    ...
# 45080                                               43.0    ...
# 48627                                               34.0    ...
# 36143                                               25.0    ...
# 41381                                               29.0    ...
# ...                                                  ...    ...
# 44262                                               49.0    ...
# 37145                                               28.0    ...
# 51325                                               34.0    ...
# 50331                                               30.0    ...
# 37173                                               42.0    ...
#
#        TRI-QUT Coeliac Study_TMA Block 1 | 026 | Segment 1  \
# 48107                                              279.0
# 45080                                              151.0
# 48627                                               80.0
# 36143                                               93.0
# 41381                                               77.0
# ...                                                  ...
# 44262                                              195.0
# 37145                                               54.0
# 51325                                              294.0
# 50331                                               85.0
# 37173                                              121.0
#
#        TRI-QUT Coeliac Study_TMA Block 1 | 026 | Segment 2  \
# 48107                                               24.0
# 45080                                               34.0
# 48627                                               24.0
# 36143                                               29.0
# 41381                                               19.0
# ...                                                  ...
# 44262                                               52.0
# 37145                                               19.0
# 51325                                               43.0
# 50331                                               25.0
# 37173                                               41.0
#
#        TRI-QUT Coeliac Study_TMA Block 1 | 027 | Segment 1  \
# 48107                                              484.0
# 45080                                              197.0
# 48627                                               63.0
# 36143                                               60.0
# 41381                                               52.0
# ...                                                  ...
# 44262                                              190.0
# 37145                                               45.0
# 51325                                              242.0
# 50331                                               84.0
# 37173                                              153.0
#
#        TRI-QUT Coeliac Study_TMA Block 1 | 027 | Segment 2  \
# 48107                                               52.0
# 45080                                               56.0
# 48627                                               40.0
# 36143                                               38.0
# 41381                                               27.0
# ...                                                  ...
# 44262                                               87.0
# 37145                                               39.0
# 51325                                               56.0
# 50331                                               39.0
# 37173                                               63.0
#
#        TRI-QUT Coeliac Study_TMA Block 1 | 028 | Segment 1  \
# 48107                                              366.0
# 45080                                               71.0
# 48627                                               20.0
# 36143                                               26.0
# 41381                                               30.0
# ...                                                  ...
# 44262                                               76.0
# 37145                                               26.0
# 51325                                              131.0
# 50331                                               28.0
# 37173                                               63.0
#
#        TRI-QUT Coeliac Study_TMA Block 1 | 028 | Segment 2  \
# 48107                                               21.0
# 45080                                               22.0
# 48627                                               16.0
# 36143                                               20.0
# 41381                                                9.0
# ...                                                  ...
# 44262                                               37.0
# 37145                                               12.0
# 51325                                               18.0
# 50331                                                9.0
# 37173                                               22.0
#
#        TRI-QUT Coeliac Study_TMA Block 1 | 029 | Segment 1  \
# 48107                                              121.0
# 45080                                              139.0
# 48627                                               97.0
# 36143                                               87.0
# 41381                                               95.0
# ...                                                  ...
# 44262                                              185.0
# 37145                                               66.0
# 51325                                              211.0
# 50331                                              114.0
# 37173                                              130.0
#
#        TRI-QUT Coeliac Study_TMA Block 1 | 029 | Segment 2  \
# 48107                                               44.0
# 45080                                               66.0
# 48627                                               36.0
# 36143                                               71.0
# 41381                                               58.0
# ...                                                  ...
# 44262                                               98.0
# 37145                                               38.0
# 51325                                               59.0
# 50331                                               37.0
# 37173                                               63.0
#
#        TRI-QUT Coeliac Study_TMA Block 1 | 030 | Segment 1  \
# 48107                                              412.0
# 45080                                              185.0
# 48627                                               89.0
# 36143                                               83.0
# 41381                                               94.0
# ...                                                  ...
# 44262                                              178.0
# 37145                                               71.0
# 51325                                              327.0
# 50331                                              109.0
# 37173                                              137.0
#
#        TRI-QUT Coeliac Study_TMA Block 1 | 030 | Segment 2
# 48107                                               53.0
# 45080                                               71.0
# 48627                                               34.0
# 36143                                               51.0
# 41381                                               42.0
# ...                                                  ...
# 44262                                               82.0
# 37145                                               35.0
# 51325                                               79.0
# 50331                                               38.0
# 37173                                               53.0
#
# [18815 rows x 191 columns]

# %% [markdown]
# ToDo: Need to check that column names are unique in SegmentProperties!! KO has 2 entries in current version, need to trace down where this has been introduced.

# %%
dropCols = ['SlideName', 'ScanLabel', 'ROILabel', 'SegmentLabel',
            'SegmentDisplayName', 'Origin Instrument ID', 'AOISurfaceArea', 
            'AOINucleiCount', 'ROICoordinateX', 'ROICoordinateY', 
            'RawReads', 'AlignedReads', 'DeduplicatedReads', 'TrimmedReads', 
            'StitchedReads', 'SequencingSaturation', 'SequencingSetID', 
            'UMIQ30', 'RTSQ30', 'GeoMxNgsPipelineVersion', 'LOT_Mouse_NGS_Whole_Transcriptome_Atlas_RNA_1_0',
            'ROIID', 'SegmentID', 'ScanWidth', 'ScanHeight', 'ScanOffsetX', 'ScanOffsetY']

keepCols = [x for x in segs.columns if not x in dropCols]

for c in keepCols:
    print(c)
    print(len(set(segs[c])))
    print(set(segs[c]))
    print()
# Out:
# Segment 1
# 2
# {'True', 'False'}
#
# Segment 2
# 2
# {'True', 'False'}
#
# QCFlags
# 5
# {'Low Surface Area,Low Negative Probe Count for Probe Kit Human NGS Whole Transcriptome Atlas RNA_1.0,Low Nuclei Count', None, 'Low Surface Area,Low Nuclei Count', 'Low Nuclei Count', 'Low Negative Probe Count for Probe Kit Human NGS Whole Transcriptome Atlas RNA_1.0'}
#
# LOT_Human_NGS_Whole_Transcriptome_Atlas_RNA_1_0
# 1
# {'HWTA21004'}
#
# Group
# 3
# {'Placebo', 'Control', 'Hookworm'}
#
# Time_point
# 4
# {'Baseline', 'Post challenge', 'Post hookworm', 'Control'}
#
# Clinical_outcome
# 3
# {'Non responder', 'Control', 'Responder'}
#
# Core
# 69
# {'001/010 17_15576_a', '002/002 18_13187_b', '003/011 17_19905_b', '001/015 18_11839_a', '003/015 17_40912_b', '001/031 17_40620_a', '001/014 18_11840_a', '001/022 18_16609_a', '002/003 18_13185_b', '003/006 17_33069_b', '001/014 17_35196_b', '001/015 17_35197_b', '001/009 17_31104_a', '003/002 18_02240_b', '001/002 18_01086_b', '001/002 17_15571_b', '001/028 17_40618_b', '003/011 18_04540_a', '001/022 18_16609_b', '002/003 18_13185_a', '001/003 18_01085_a', '001/015 18_11839_b', '003/006 17_33069_a', '001/003 18_01085_b', '003/019 17_46386_b', '003/015 18_00548_b', '003/006 18_11645_b', '001/015 17_35197_a', '002/002 18_13187_a', '001/025 18_26917_a', '001/010 18_01091_a', '003/019 17_46386_a', '001/001 17_15573_a', '001/003 17_15574_a', '001/025 18_26917_b', '001/031 17_40620_b', '001/028 18_01087_b', '001/028 17_40618_a', '001/028 18_33529_a', '003/011 18_04540_b', '002/002 17_25398_a', '001/002 17_15571_a', '001/009 17_15575_b', '001/009 18_07953_a', '003/002 17_18624_a', '001/014 17_15569_a', '002/002 17_25398_b', '003/006 17_17727_b', '001/002 18_01086_a', '001/010 17_15576_b', '001/009 18_07953_b', '001/001 17_15573_b', '003/006 18_11645_a', '003/015 17_40912_a', '003/015 18_00548_a', '001/025 17_40619_b', '001/028 18_33529_b', '001/025 17_40619_a', '001/014 18_11840_b', '001/003 17_15574_b', '003/006 17_17727_a', '001/028 18_01087_a', '003/002 18_02240_a', '001/001 18_01088_b', '001/014 17_15569_b', '001/018 17_29377', '003/011 17_19905_a', '003/015 18_32656_a', '001/009 17_15575_a'}

# %%
segs
# Out:
#                                                                          SlideName  \
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 1  TRI-QUT Coeliac Study_TMA Block 4
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 2  TRI-QUT Coeliac Study_TMA Block 4
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 1  TRI-QUT Coeliac Study_TMA Block 4
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 2  TRI-QUT Coeliac Study_TMA Block 4
# TRI-QUT Coeliac Study_TMA Block 4_003_Segment 1  TRI-QUT Coeliac Study_TMA Block 4
# ...                                                                            ...
# TRI-QUT Coeliac Study_TMA Block 1_028_Segment 2  TRI-QUT Coeliac Study_TMA Block 1
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 1  TRI-QUT Coeliac Study_TMA Block 1
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 2  TRI-QUT Coeliac Study_TMA Block 1
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 1  TRI-QUT Coeliac Study_TMA Block 1
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 2  TRI-QUT Coeliac Study_TMA Block 1
#
#                                                                          ScanLabel  \
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 1  TRI-QUT Coeliac Study_TMA Block 4
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 2  TRI-QUT Coeliac Study_TMA Block 4
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 1  TRI-QUT Coeliac Study_TMA Block 4
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 2  TRI-QUT Coeliac Study_TMA Block 4
# TRI-QUT Coeliac Study_TMA Block 4_003_Segment 1  TRI-QUT Coeliac Study_TMA Block 4
# ...                                                                            ...
# TRI-QUT Coeliac Study_TMA Block 1_028_Segment 2  TRI-QUT Coeliac Study_TMA Block 1
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 1  TRI-QUT Coeliac Study_TMA Block 1
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 2  TRI-QUT Coeliac Study_TMA Block 1
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 1  TRI-QUT Coeliac Study_TMA Block 1
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 2  TRI-QUT Coeliac Study_TMA Block 1
#
#                                                 ROILabel SegmentLabel  \
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 1      001    Segment 1
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 2      001    Segment 2
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 1      002    Segment 1
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 2      002    Segment 2
# TRI-QUT Coeliac Study_TMA Block 4_003_Segment 1      003    Segment 1
# ...                                                  ...          ...
# TRI-QUT Coeliac Study_TMA Block 1_028_Segment 2      028    Segment 2
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 1      029    Segment 1
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 2      029    Segment 2
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 1      030    Segment 1
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 2      030    Segment 2
#
#                                                                                 SegmentDisplayName  \
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 1  TRI-QUT Coeliac Study_TMA Block 4 | 001 | Segm...
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 2  TRI-QUT Coeliac Study_TMA Block 4 | 001 | Segm...
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 1  TRI-QUT Coeliac Study_TMA Block 4 | 002 | Segm...
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 2  TRI-QUT Coeliac Study_TMA Block 4 | 002 | Segm...
# TRI-QUT Coeliac Study_TMA Block 4_003_Segment 1  TRI-QUT Coeliac Study_TMA Block 4 | 003 | Segm...
# ...                                                                                            ...
# TRI-QUT Coeliac Study_TMA Block 1_028_Segment 2  TRI-QUT Coeliac Study_TMA Block 1 | 028 | Segm...
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 1  TRI-QUT Coeliac Study_TMA Block 1 | 029 | Segm...
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 2  TRI-QUT Coeliac Study_TMA Block 1 | 029 | Segm...
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 1  TRI-QUT Coeliac Study_TMA Block 1 | 030 | Segm...
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 2  TRI-QUT Coeliac Study_TMA Block 1 | 030 | Segm...
#
#                                                 Origin Instrument ID  \
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 1            2001G0086
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 2            2001G0086
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 1            2001G0086
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 2            2001G0086
# TRI-QUT Coeliac Study_TMA Block 4_003_Segment 1            2001G0086
# ...                                                              ...
# TRI-QUT Coeliac Study_TMA Block 1_028_Segment 2            2001G0086
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 1            2001G0086
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 2            2001G0086
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 1            2001G0086
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 2            2001G0086
#
#                                                 Segment 1 Segment 2 QCFlags  \
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 1      True     False    None
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 2     False      True    None
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 1      True     False    None
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 2     False      True    None
# TRI-QUT Coeliac Study_TMA Block 4_003_Segment 1      True     False    None
# ...                                                   ...       ...     ...
# TRI-QUT Coeliac Study_TMA Block 1_028_Segment 2     False      True    None
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 1      True     False    None
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 2     False      True    None
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 1      True     False    None
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 2     False      True    None
#
#                                                  AOISurfaceArea  ...  \
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 1    41162.306660  ...
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 2    37706.250098  ...
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 1    36039.266939  ...
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 2    50750.904001  ...
# TRI-QUT Coeliac Study_TMA Block 4_003_Segment 1    51688.829455  ...
# ...                                                         ...  ...
# TRI-QUT Coeliac Study_TMA Block 1_028_Segment 2    20138.873102  ...
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 1    46876.795236  ...
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 2    50995.242845  ...
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 1    56949.636379  ...
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 2    38772.441568  ...
#
#                                                     Group      Time_point  \
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 1   Control         Control
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 2   Control         Control
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 1  Hookworm  Post challenge
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 2  Hookworm  Post challenge
# TRI-QUT Coeliac Study_TMA Block 4_003_Segment 1   Placebo  Post challenge
# ...                                                   ...             ...
# TRI-QUT Coeliac Study_TMA Block 1_028_Segment 2   Placebo        Baseline
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 1  Hookworm   Post hookworm
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 2  Hookworm   Post hookworm
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 1  Hookworm   Post hookworm
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 2  Hookworm   Post hookworm
#
#                                                  Clinical_outcome  \
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 1           Control
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 2           Control
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 1     Non responder
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 2     Non responder
# TRI-QUT Coeliac Study_TMA Block 4_003_Segment 1         Responder
# ...                                                           ...
# TRI-QUT Coeliac Study_TMA Block 1_028_Segment 2     Non responder
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 1         Responder
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 2         Responder
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 1         Responder
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 2         Responder
#
#                                                                Core  \
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 1    001/018 17_29377
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 2    001/018 17_29377
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 1  001/015 18_11839_a
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 2  001/015 18_11839_a
# TRI-QUT Coeliac Study_TMA Block 4_003_Segment 1  002/002 18_13187_a
# ...                                                             ...
# TRI-QUT Coeliac Study_TMA Block 1_028_Segment 2  001/010 17_15576_b
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 1  003/015 18_00548_a
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 2  003/015 18_00548_a
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 1  003/015 18_00548_b
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 2  003/015 18_00548_b
#
#                                                                                 ROIID  \
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 1  810d3b02-f857-4695-a318-a96bd4809c13
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 2  810d3b02-f857-4695-a318-a96bd4809c13
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 1  b347940b-a902-4a7f-87b5-ed044f98e0e2
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 2  b347940b-a902-4a7f-87b5-ed044f98e0e2
# TRI-QUT Coeliac Study_TMA Block 4_003_Segment 1  0a1d6f54-3e12-4ead-88f9-9ecd5ead5c77
# ...                                                                               ...
# TRI-QUT Coeliac Study_TMA Block 1_028_Segment 2  2e3bd7e8-3898-4a87-a481-b7851133b65e
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 1  3fb36b84-e580-485b-8fd4-05c748bc6ce2
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 2  3fb36b84-e580-485b-8fd4-05c748bc6ce2
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 1  064f8316-b93e-4b4e-895f-99932d936f32
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 2  064f8316-b93e-4b4e-895f-99932d936f32
#
#                                                                             SegmentID  \
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 1  50a4b52d-c29f-4c0c-b4f9-5231ad0b8bb6
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 2  ede3e81a-8804-4234-84a4-e6d808f68860
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 1  5a86ee5b-ce6b-4f79-b11e-3d844b8d5bae
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 2  c0d67878-b053-4d3b-a898-cdc91b00abb8
# TRI-QUT Coeliac Study_TMA Block 4_003_Segment 1  733e608f-0803-4dd9-8a6f-e2fac125825b
# ...                                                                               ...
# TRI-QUT Coeliac Study_TMA Block 1_028_Segment 2  605284a8-c955-4b17-b60f-f8e458bca7b7
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 1  12aa7779-b9cf-4e09-ad43-96e638779053
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 2  763f9a1c-710e-45e3-80ff-cbac982767c8
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 1  8cf8847f-4d98-4355-892e-eac5d00fdfa4
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 2  b8876afb-5c3c-4a0b-84e4-b7ad1148b802
#
#                                                     ScanWidth    ScanHeight  \
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 1  18690.275391  70258.562500
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 2  18690.275391  70258.562500
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 1  18690.275391  70258.562500
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 2  18690.275391  70258.562500
# TRI-QUT Coeliac Study_TMA Block 4_003_Segment 1  18690.275391  70258.562500
# ...                                                       ...           ...
# TRI-QUT Coeliac Study_TMA Block 1_028_Segment 2  13164.822266  68415.953125
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 1  13164.822266  68415.953125
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 2  13164.822266  68415.953125
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 1  13164.822266  68415.953125
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 2  13164.822266  68415.953125
#
#                                                  ScanOffsetX ScanOffsetY
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 1       7039.0      5830.0
# TRI-QUT Coeliac Study_TMA Block 4_001_Segment 2       7039.0      5830.0
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 1       7039.0      5830.0
# TRI-QUT Coeliac Study_TMA Block 4_002_Segment 2       7039.0      5830.0
# TRI-QUT Coeliac Study_TMA Block 4_003_Segment 1       7039.0      5830.0
# ...                                                      ...         ...
# TRI-QUT Coeliac Study_TMA Block 1_028_Segment 2       1609.0      6752.0
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 1       1609.0      6752.0
# TRI-QUT Coeliac Study_TMA Block 1_029_Segment 2       1609.0      6752.0
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 1       1609.0      6752.0
# TRI-QUT Coeliac Study_TMA Block 1_030_Segment 2       1609.0      6752.0
#
# [191 rows x 34 columns]

# %%
set(segs['SlideName'])
# Out:
# {'TRI-QUT Coeliac Study_TMA Block 1',
#  'TRI-QUT Coeliac Study_TMA Block 2',
#  'TRI-QUT Coeliac Study_TMA Block 3',
#  'TRI-QUT Coeliac Study_TMA Block 4'}

# %%
expSlideDict = {}
expSlideDict['exp1'] = {'SlideName': ['PFAC_Liver_CD63_CD45_Col1A1']}
expSlideDict['exp2'] = {'SlideName': ['SFAC_Female_2_SMA_CD45_Col1A1']}
expSlideDict['exp3'] = {'SlideName': ['SKC_Liver_Female_2_SMA_CD45_Col1A1',
                         'SKC_Liver_Male_SMA_CD45_Col1A1',
                         'SKC_Male_Liver_2_SMA_CD45_Col1A1']}

exps = ['exp1', 'exp2', 'exp3']

# %%
expIndices = {}


for exp in exps:
    print(exp)

    thisExp = expSlideDict[exp]
    slideNames = thisExp['SlideName']

    masterIndex = []
    
    for s in slideNames:
        # print('s')
        # print(s)
        thisIndex = segs[segs['SlideName'] == s].index
        # print(list(thisIndex))
        masterIndex.extend(list(thisIndex))
    
    expIndices[exp] = masterIndex
# Out:
# exp1
# exp2
# exp3

# %%
expIndices
# Out:
# {'exp1': [], 'exp2': [], 'exp3': []}

# %%
expIndices
# Out:
# {'exp1': [], 'exp2': [], 'exp3': []}

# %%
for k,exp in expIndices.items():
    # print(exp)
    print(k)
    print(len(exp))
# Out:
# exp1
# 0
# exp2
# 0
# exp3
# 0

# %% [markdown]
# ToDo: Export experimental sets for use in StandR or RUV
#
#
#  - StandR => countFile, featureAnnoFile, sampleAnnoFile
#  - RUV.   => ???

# %% [raw]
# ToDo: Read in previously dropped columns and only display remaining columns as options

# %% [markdown]
# ToDo: Choose column(s) to use for setting up primary experiment sets (eg. slide name) (save as nested dictionary (experiment name : column : value)
# ToDo: Choose column variables to use for setting up secondary experiment sets  (save as nested dictionary (experiment name : columns : [values])

# %%
break
# Out:
#   Cell In[19], line 1
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
sampleInfoExternal = masterData.segData.copy()

# %%
sampleInfoExternal.columns

# %%
sampleInfoExternal['TrimmedReads']

# %%
print(masterData.probeClass)
print(masterData.probeClassDict)
# dataLog1External, sampleInfoExternal = masterData.drop_AOIs('#16_9', writeOrig=True)

nuclei = sampleInfoExternal['AOINucleiCount']
# print(nuclei)
surfArea = sampleInfoExternal['AOISurfaceArea']
# print(surfArea)

# dataLog1External, sampleInfoExternal = masterData.add_class_mean(masterData.dataLog1)

# %%
slides = set(segs['SlideName'])

colLookup = dict(zip(slides,range(len(slides))))

# %%
colLookup

# %%
colMap = [colLookup[x]/len(slides) for x in segs['SlideName']]

# colMap = [colLookup[x] for x in segs['SlideName']]

# %%
colMap
